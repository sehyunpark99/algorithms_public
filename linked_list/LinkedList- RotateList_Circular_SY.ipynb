# %% [markdown]
# ### 61. Rotate List

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 마지막 노드가 첫번째 노드를 가르키게 만들어서 circular list 로 만듬
# - 첫번째 노드를 찾고, 마지막 노드를 새로 지정해 주는 과정을 거침

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def rotateRight(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        if not head:
            return None
        lastElement = head
        length = 1
        #list의 길이 / 마지막 node 구하기
        while ( lastElement.next ):
            lastElement = lastElement.next
            length += 1
        k = k % length #k = length일 경우 k= 0이 되게끔 
        lastElement.next = head #마지막 node가 첫번째 노드를 가리킴 (circular로 만듬)
        tempNode = head
        for _ in range( length - k - 1 ): 
            tempNode = tempNode.next # 마지막 노드가 될 애를 구함 
        answer = tempNode.next #첫번째 노드 지정
        tempNode.next = None #마지막 노드로 만들어버림
        
        return answer
