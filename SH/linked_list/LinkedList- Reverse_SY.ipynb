# %% [markdown]
# ### 206. Reverse Linked List

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 현재 curnode는 prev가 되고 => 그다음 loop에서 curnode 뒤에 prev를 연결해주면서 순서를 바꿈
#
# - next : 그다음 loop에 curNode를 새로 지정해주는 역할
# - curNode.next : 현재 curnode와 prev를 연결 (2-1-None)
# - prev : 다음 loop에서의 curNode (현재 next)와 연결되기 위해 현재 curNode를 prev로 지정
# - curNode : next로 지정

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev = None
        curNode = head
        next = None
        while curNode:
            next = curNode.next 
            curNode.next = prev
            prev = curNode
            curNode = next
        return prev

# %% [markdown]
# ### 1721. Swapping Nodes in a Linked List

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - first는 k번째 노드
# - 임시 node (tail)은 끝에서 k번째 노드를 찾는 역할
# - second는 lengh - k 번째 노드가 됨
# - first, second value swap하기

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def swapNodes(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        first = second = head
        for _ in range(k - 1):
            first = first.next

        tail = first
        #"first"가 이미 k-1만큼 앞으로 이동했고, "tail"도 "first"와 같은 위치에서 시작했기 때문에 "tail"이 리스트의 끝에 도달하면 "second"는 length - k만큼 이동한 위치에 있게됨
        while tail.next:
            second = second.next
            tail = tail.next 

        first.val, second.val = second.val, first.val
        return head
